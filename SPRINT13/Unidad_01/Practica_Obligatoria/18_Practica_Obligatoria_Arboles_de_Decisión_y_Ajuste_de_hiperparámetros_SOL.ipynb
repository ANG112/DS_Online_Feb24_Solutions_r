# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: **Arboles de Decisión y Ajuste de hiperparámetros**

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en encontrar el mejor modelo para resolver un problema de predicción de si los destinatarios de una campaña de marketing adquirirán un producto concreto. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %% [markdown]
# ### Descripción
#
# En el directorio data encontrarás un dataset que contiene datos relacionados con campañas de marketing directo de una institución bancaria portuguesa (es el dataset "Bank Marketing" de la UCI Machine Learning Repository). Los datos se recopilaron de campañas de marketing telefónico, donde el objetivo principal era predecir si el cliente se suscribiría a un depósito a plazo.

# %% [markdown]
# La práctica consiste en completar el proceso de creación de un modelo basado en árboles de decisión que permita predecir si un cliente (dadas unas características similares a las del dataset) "comprará" el depósito a plazo. Sigue los pasos necesarios de un proceso de ML para crear el modelo, optimizar sus hiperparámetros, comparar los resultados de esa optimización con una regresión logística (sin optimizar, con sus hiperparámetros por defecto) y finalmente evaluarlo contra test y hacer una pequeña valoración del resultado obtenido.
#
# Tendrás que hacer la limpieza, split, minieda, selección, tratamiento, primeros entrenamientos, optimización, comparación y evaluación según tu mejor criterio. Eso sí, es obligatorio:
# - Identificar el target y analizar su distribución
# - Realizar una optimización de hiperparámetros, escogiendo un grid medianemante razonado
# - Comparar con el modelo baseline
# - Evaluar contra test

# %% [markdown]
# AYUDA: La dirección del banco nos proporciona estas notas (en inglés):
#
#
#    **bank client data:**
#    1 - age (numeric)
#    2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
#                                        "blue-collar","self-employed","retired","technician","services")
#    3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#    4 - education (categorical: "unknown","secondary","primary","tertiary")
#    5 - default: has credit in default? (binary: "yes","no")
#    6 - balance: average yearly balance, in euros (numeric)
#    7 - housing: has housing loan? (binary: "yes","no")
#    8 - loan: has personal loan? (binary: "yes","no")
#
#    **related with the last contact of the current campaign:**
#    9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
#   10 - day: last contact day of the month (numeric)
#   11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#   12 - duration: last contact duration, in seconds (numeric)
#
#    **other attributes:**
#   13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#   14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#   15 - previous: number of contacts performed before this campaign and for this client (numeric)
#   16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")

# %% [markdown]
# ### IMPORTS

# %%
import bootcampviztools as bt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.metrics import ConfusionMatrixDisplay, classification_report,make_scorer,recall_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### PRIMER VISTAZO

# %%
df = pd.read_csv("./data/bank-full.csv", sep = ";")

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
target = "y"

# %%
# Analisis de "unkown"

for col in df.columns:
    print(f"Para {col}, unkowns o missings:", end = " ")
    try:
        missings = df[col].value_counts()["unknown"]
        print(f"{missings}, {round(missings/len(df)*100.0,2)}%")
    except:
        print(0)
# Out:
# Para age, unkowns o missings: 0
# Para job, unkowns o missings: 288, 0.64%
# Para marital, unkowns o missings: 0
# Para education, unkowns o missings: 1857, 4.11%
# Para default, unkowns o missings: 0
# Para balance, unkowns o missings: 0
# Para housing, unkowns o missings: 0
# Para loan, unkowns o missings: 0
# Para contact, unkowns o missings: 13020, 28.8%
# Para day, unkowns o missings: 0
# Para month, unkowns o missings: 0
# Para duration, unkowns o missings: 0
# Para campaign, unkowns o missings: 0
# Para pdays, unkowns o missings: 0
# Para previous, unkowns o missings: 0
# Para poutcome, unkowns o missings: 36959, 81.75%
# Para y, unkowns o missings: 0

# %%
df.shape
# Out:
# (45211, 17)

# %%
# Miro con más detalle las que tienen un porcentaje alto (contact y poutcome)
df.poutcome.value_counts()
# Out:
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64

# %% [markdown]
# *Me la quedo provisionalmente, lo que tendré que entender es el encoding*

# %%
df.contact.value_counts()
# Out:
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64

# %% [markdown]
# *Ocurre igual que con el campo anterior, por ahora me lo quedo y al analizarla bivariantemente con el target ya decidiré*

# %% [markdown]
# *En definitiva, las variables con "faltantes" o "unkowns" son todas categóricas, los missings los considero un valor más y veo en el bivariante qué hacer.*

# %% [markdown]
# ### TRAIN/TEST

# %%
train_set, test_set = train_test_split(df, test_size= 0.2, stratify=df['y'],random_state= 42)

# %% [markdown]
# ### MINIEDA

# %%
#### Distribución del target

# %%
bt.pinta_distribucion_categoricas(train_set, [target], relativa= True, mostrar_valores= True)

# %% [markdown]
# *Esto es un ejemplo claro de target no equilibrado o desbalanceado. Por lo menos usaremos hoy el hiperparámetro de class_weight*

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36168 entries, 24001 to 44229
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        36168 non-null  int64
#  1   job        36168 non-null  object
#  2   marital    36168 non-null  object
#  3   education  36168 non-null  object
#  4   default    36168 non-null  object
#  5   balance    36168 non-null  int64
#  6   housing    36168 non-null  object
#  7   loan       36168 non-null  object
#  8   contact    36168 non-null  object
#  9   day        36168 non-null  int64
#  10  month      36168 non-null  object
#  11  duration   36168 non-null  int64
#  12  campaign   36168 non-null  int64
#  13  pdays      36168 non-null  int64
#  14  previous   36168 non-null  int64
#  15  poutcome   36168 non-null  object
#  16  y          36168 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.0+ MB

# %%
train_set.y.value_counts(True)
# Out:
# y
# no     0.883018
# yes    0.116982
# Name: proportion, dtype: float64

# %%
test_set.y.value_counts(True)
# Out:
# y
# no     0.883003
# yes    0.116997
# Name: proportion, dtype: float64

# %%
train_set_bck = train_set.copy()

# %%
features_cat = train_set.select_dtypes(include = "object").columns.to_list()
if target in features_cat:
    features_cat.remove(target)
features_cat
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome']

# %%
features_num = [col for col in train_set.columns if col not in features_cat and col != target]
features_num
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
### Analizamos categóricas

for col in features_cat:
    bt.plot_categorical_relationship_fin(train_set, target, col, relative_freq= True, show_values= True)

# %% [markdown]
# *Proceso para probar job y month*

# %%
features_cat_sel1 = ["job","housing","contact","poutcome"]
features_cat_sel2 = ["marital", "education","loan","month"]
pobrecillas = ["default"]

# %%
onehot = ['job','contact','poutcome']

# %%
for col in features_num:
    bt.plot_grouped_histograms(train_set, cat_col= target, num_col= col, group_size= 2)

# %%
features_num = ["age","day","duration","pdays"]
features_num_2 = ["previous"]

# %% [markdown]
# ### Tratamiento

# %% [markdown]
# Categóricas:

# %%
train_set["housing"] = train_set["housing"] == "yes"
train_set["loan"] = train_set["loan"] == "yes"
features_cat.remove("housing")
features_cat.remove("loan")

# %%
test_set["housing"] = test_set["housing"] == "yes"
test_set["loan"] = test_set["loan"] == "yes"

# %%
onehot
# Out:
# ['job', 'contact', 'poutcome']

# %%
train_set = pd.get_dummies(train_set, columns = onehot, dtype = int)
test_set = pd.get_dummies(test_set, columns = onehot, dtype = int)

# %%
mapeo = {
    'ene':1,
    'feb':2,
    'mar':3,
    'apr':4,
    'may':5,
    'jun':6,
    'jul':7,
    'aug':8,
    'sep':9,
    'oct':10,
    'nov':11,
    'dec':12
}

# %%
train_set['month'] = train_set['month'].map(mapeo)
test_set['month'] = test_set['month'].map(mapeo)

# %% [markdown]
# features_num: En principio no pasa nada por no escalar, podemos hacerlo  y probar dos modelos. Pero como hacer un baseline con logística, a la logística sí que le afecta y bastante.

# %%
train_set[features_num].hist()
plt.tight_layout()

# %%
train_set["contacted_before"] = train_set["pdays"].apply(lambda row: 1 if row >= 0 else 0)
train_set.contacted_before.value_counts(True)
# Out:
# contacted_before
# 0    0.817961
# 1    0.182039
# Name: proportion, dtype: float64

# %%
test_set["contacted_before"] = test_set["pdays"].apply(lambda row: 1 if row >= 0 else 0)

# %%
bt.plot_categorical_relationship_fin(train_set, target, "contacted_before", relative_freq= True, show_values= True)

# %%
#bt.plot_grouped_histograms(train_set[train_set.contacted_before == 1], cat_col= target, num_col= "pdays", group_size= 2)

# %%
train_set["contacted_before"] = train_set["pdays"] != -1
features_cat_sel1.append("contacted_before")
test_set["contacted_before"] = test_set["pdays"] != -1
train_set_scaled = train_set.copy()
test_set_scaled = test_set.copy()

# %%
features_num
# Out:
# ['age', 'day', 'duration', 'pdays']

# %%
train_set_scaled["duration"] = np.log(train_set_scaled["duration"] + 1)
train_set_scaled["pdays"] = np.log(train_set_scaled["pdays"] + 2)

# %%
test_set_scaled["duration"] = np.log(test_set_scaled["duration"] + 1)
test_set_scaled["pdays"] = np.log(test_set_scaled["duration"] + 2)

# %%
train_set_scaled[features_num]
# Out:
#        age  day  duration     pdays
# 24001   36   29  4.948760  0.000000
# 43409   24    5  6.811244  5.231109
# 20669   44   12  7.459339  0.000000
# 18810   48   31  3.583519  0.000000
# 23130   38   26  4.060443  0.000000
# ...    ...  ...       ...       ...
# 17958   50   30  4.077537  0.000000
# 15941   36   22  4.356709  0.000000
# 16952   45   25  4.595120  0.000000
# 34781   27    6  5.429346  0.000000
# 44229   60   19  5.159055  5.746203
#
# [36168 rows x 4 columns]

# %%
train_set_scaled[features_num].hist()
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'day'}>],
#        [<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'pdays'}>]], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_set_scaled[features_num] = scaler.fit_transform(train_set_scaled[features_num])
test_set_scaled[features_num] = scaler.transform(test_set_scaled[features_num])

# %% [markdown]
# ### Importamos modelos, entrenamos, creamos el baseline

# %%
features_cat_sel1.remove('job')
#features_cat_sel1.remove('contacted_before')
features_cat_sel1.remove('contacted_before')

# %%
#x_train = train_set[features]

# %%
features_encoded_cat_sel1 = []
for col in features_cat_sel1:
    defintive_col = [col_2 for col_2 in train_set.columns if col_2.startswith(col)]
    features_encoded_cat_sel1 += defintive_col
features_encoded_cat_sel1
# Out:
# ['housing',
#  'contact_cellular',
#  'contact_telephone',
#  'contact_unknown',
#  'contacted_before',
#  'poutcome_failure',
#  'poutcome_other',
#  'poutcome_success',
#  'poutcome_unknown']

# %%
features_encoded_cat_sel1.remove('contacted_before')

# %%
#print(features_encoded_cat_sel1)

# %%
features_encoded_cat_sel1
# Out:
# ['housing',
#  'contact_cellular',
#  'contact_telephone',
#  'contact_unknown',
#  'poutcome_failure',
#  'poutcome_other',
#  'poutcome_success',
#  'poutcome_unknown']

# %%
def convertir(row):
    return 1 if row == "yes" else 0 


train_set[target] = train_set[target].apply(lambda row: 1 if row == "yes" else 0) # apply(convertir)
test_set[target] = test_set[target].apply(lambda row: 1 if row == "yes" else 0)

# %%
X_train = train_set[features_encoded_cat_sel1 + features_num].copy()
X_train_scaled = train_set_scaled[features_encoded_cat_sel1 + features_num].copy()
y_train = train_set[target]
X_test = test_set[features_encoded_cat_sel1 + features_num].copy()
X_test_scaled = test_set_scaled[features_encoded_cat_sel1 + features_num].copy()
y_test = test_set[target]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

lr_clf = LogisticRegression(max_iter = 1000)
tree_clf = DecisionTreeClassifier(random_state= 42)

lr_clf.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
print(classification_report(y_test, lr_clf.predict(X_test_scaled)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95      7985
#            1       0.65      0.30      0.42      1058
#
#     accuracy                           0.90      9043
#    macro avg       0.78      0.64      0.68      9043
# weighted avg       0.88      0.90      0.88      9043

# %%
lr_clf.fit(X_train, y_train)
print(classification_report(y_test, lr_clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      7985
#            1       0.65      0.31      0.42      1058
#
#     accuracy                           0.90      9043
#    macro avg       0.78      0.64      0.68      9043
# weighted avg       0.88      0.90      0.88      9043

# %%
tree_clf.fit(X_train, y_train)
print(classification_report(y_train, tree_clf.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     31937
#            1       1.00      1.00      1.00      4231
#
#     accuracy                           1.00     36168
#    macro avg       1.00      1.00      1.00     36168
# weighted avg       1.00      1.00      1.00     36168

# %%
#from sklearn.model_selection import cross_val_score
#print(np.mean(cross_val_score(tree_clf,X_train,y_train,cv=5,scoring='balanced_accuracy')))
tree_clf
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#from sklearn.metrics import recall_score,make_scorer
#print(np.mean(cross_val_score(tree_clf,X_train,y_train,cv=5,scoring=make_scorer(recall_score,pos_label=1))))

# %% [markdown]
# ### Balanced accuracy es el recall medio

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "max_depth": [1,2,8,10],
    "min_samples_leaf": [1,10,20,100],
    "class_weight": ["balanced",None]
}

tree_grid = GridSearchCV( tree_clf,
                        param_grid= param_grid,
                        cv = 5,
                        scoring = make_scorer(recall_score,pos_label=1) # Depende de "Negocio" del impacto en el problema de negocio
)
tree_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'class_weight': ['balanced', None],
#                          'max_depth': [1, 2, 8, 10],
#                          'min_samples_leaf': [1, 10, 20, 100]},
#              scoring=make_scorer(recall_score, response_method='predict', pos_label=1))

# %%
tree_grid.best_params_
# Out:
# {'class_weight': 'balanced', 'max_depth': 8, 'min_samples_leaf': 20}

# %%
tree_grid.best_score_
# Out:
# 0.8397601324100357

# %%
y_pred_train = tree_grid.best_estimator_.predict(X_train)
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.79      0.87     31937
#            1       0.35      0.87      0.50      4231
#
#     accuracy                           0.80     36168
#    macro avg       0.67      0.83      0.69     36168
# weighted avg       0.91      0.80      0.83     36168

# %%
y_pred = tree_grid.best_estimator_.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87      7985
#            1       0.34      0.83      0.48      1058
#
#     accuracy                           0.79      9043
#    macro avg       0.66      0.81      0.67      9043
# weighted avg       0.90      0.79      0.82      9043

# %% [markdown]
# #### El 0.87 del recall para la clase positiva está muy bien, pero es a costa de una precisión muy baja en la clase positiva: lo que equivale a hacer el test a casi todos los de la población, así seguro que no fallas en ningún positivo. Probemos una estrategia de entrenamiento menos agresiva, otro scoring.

# %%
tree_grid.best_estimator_.feature_importances_
# Out:
# array([7.65739363e-02, 1.67499938e-03, 0.00000000e+00, 1.12775321e-01,
#        1.40340202e-03, 1.93794108e-04, 1.65195180e-01, 0.00000000e+00,
#        4.73834383e-02, 2.26317024e-02, 5.42919452e-01, 2.92487742e-02])

# %% [markdown]
# #### Esto tiene mala pinta

# %%
tree_grid.best_estimator_.feature_names_in_
# Out:
# array(['housing', 'contact_cellular', 'contact_telephone',
#        'contact_unknown', 'poutcome_failure', 'poutcome_other',
#        'poutcome_success', 'poutcome_unknown', 'age', 'day', 'duration',
#        'pdays'], dtype=object)

# %%
feature_importances = pd.DataFrame({"features": tree_grid.best_estimator_.feature_names_in_, "importance": tree_grid.best_estimator_.feature_importances_})
feature_importances.sort_values('importance',ascending=False,inplace=True)
sns.barplot(data=feature_importances,x='importance',y='features',palette='viridis')
plt.title('RandomForest base on train data (best model)')
# Out:
# Text(0.5, 1.0, 'RandomForest base on train data (best model)')

# %%
#features_cat_sel1.remove('contacted_before')

# %% [markdown]
# #### Lo dicho, mala pinta las features.
# #### Ahora probamos con una función de scoring de recall balanceado entre las dos clases: balanced_accuracy (ya, el nombre está fatal puesto)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "max_depth": [8,10,20,40],
    "min_samples_leaf": [10,20,100,200],
    "class_weight": ["balanced",None]
}

tree_grid = GridSearchCV( tree_clf,
                        param_grid= param_grid,
                        cv = 5,
                        scoring = "balanced_accuracy" # Depende de "Negocio" del impacto en el problema de negocio
)
tree_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'class_weight': ['balanced', None],
#                          'max_depth': [8, 10, 20, 40],
#                          'min_samples_leaf': [10, 20, 100, 200]},
#              scoring='balanced_accuracy')

# %%
tree_grid.best_params_
# Out:
# {'class_weight': 'balanced', 'max_depth': 20, 'min_samples_leaf': 100}

# %%
y_pred_train = tree_grid.best_estimator_.predict(X_train)
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.79      0.87     31937
#            1       0.35      0.87      0.50      4231
#
#     accuracy                           0.80     36168
#    macro avg       0.67      0.83      0.69     36168
# weighted avg       0.91      0.80      0.83     36168

# %%
y_pred = tree_grid.best_estimator_.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.78      0.87      7985
#            1       0.34      0.84      0.48      1058
#
#     accuracy                           0.79      9043
#    macro avg       0.66      0.81      0.67      9043
# weighted avg       0.90      0.79      0.82      9043

# %% [markdown]
# #### Este modelo equilibra más la precisión sin una gran pérdida de recall para la clase positiva. Además nos da hiperparámetros que aportan más certeza. También las feature_importances nos dan seguridad sobre el nuevo modelo.

# %%
tree_grid.best_score_
# Out:
# 0.8166069625901843

# %%
tree_grid.best_estimator_.feature_importances_
# Out:
# array([7.66504467e-02, 1.71048493e-03, 0.00000000e+00, 1.13583117e-01,
#        1.26705695e-03, 3.88132866e-04, 1.63970933e-01, 0.00000000e+00,
#        4.71426917e-02, 2.85377618e-02, 5.47189818e-01, 1.95595567e-02])

# %%
feature_importances = pd.DataFrame({"features": tree_grid.best_estimator_.feature_names_in_, "importance": tree_grid.best_estimator_.feature_importances_})
feature_importances.sort_values('importance',ascending=False,inplace=True)
sns.barplot(data=feature_importances,x='importance',y='features',palette='viridis')
plt.title('RandomForest base on train data (best model)')
# Out:
# Text(0.5, 1.0, 'RandomForest base on train data (best model)')

# %% [markdown]
# #### Parece que job no aporta nada

# %%
#for col in features_cat:
#    bt.plot_categorical_relationship_fin(train_set, target, col, relative_freq= True, show_values= True)
features_cat
# Out:
# ['job', 'marital', 'education', 'default', 'contact', 'month', 'poutcome']

# %%
train_set_bck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36168 entries, 24001 to 44229
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        36168 non-null  int64
#  1   job        36168 non-null  object
#  2   marital    36168 non-null  object
#  3   education  36168 non-null  object
#  4   default    36168 non-null  object
#  5   balance    36168 non-null  int64
#  6   housing    36168 non-null  object
#  7   loan       36168 non-null  object
#  8   contact    36168 non-null  object
#  9   day        36168 non-null  int64
#  10  month      36168 non-null  object
#  11  duration   36168 non-null  int64
#  12  campaign   36168 non-null  int64
#  13  pdays      36168 non-null  int64
#  14  previous   36168 non-null  int64
#  15  poutcome   36168 non-null  object
#  16  y          36168 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.0+ MB

# %%
bt.plot_categorical_relationship_fin(train_set_bck, target, 'job', relative_freq= True, show_values= True)

# %%
bt.plot_categorical_relationship_fin(train_set, target, 'contacted_before', relative_freq= True, show_values= True)

# %%
bt.plot_categorical_relationship_fin(train_set_bck, target, 'poutcome', relative_freq= True, show_values= True)

# %%
from sklearn.tree import plot_tree
fig = plt.figure(figsize=(35,35))
plot_tree(tree_grid.best_estimator_)
# Out:
# [Text(0.5866188226744186, 0.9545454545454546, 'x[10] <= 250.5\ngini = 0.5\nsamples = 36168\nvalue = [18084.0, 18084.0]'),
#  Text(0.37990552325581395, 0.8636363636363636, 'x[6] <= 0.5\ngini = 0.392\nsamples = 23646\nvalue = [12770.972, 4667.39]'),
#  Text(0.25690406976744184, 0.7727272727272727, 'x[10] <= 129.5\ngini = 0.333\nsamples = 23059\nvalue = [12609.028, 3380.866]'),
#  Text(0.11300872093023256, 0.6818181818181818, 'x[10] <= 77.5\ngini = 0.169\nsamples = 12223\nvalue = [6828.286, 700.963]'),
#  Text(0.055232558139534885, 0.5909090909090909, 'x[10] <= 60.5\ngini = 0.045\nsamples = 5729\nvalue = [3233.795, 76.935]'),
#  Text(0.029069767441860465, 0.5, 'x[8] <= 29.5\ngini = 0.02\nsamples = 3796\nvalue = [2146.615, 21.371]'),
#  Text(0.011627906976744186, 0.4090909090909091, 'x[9] <= 9.5\ngini = 0.102\nsamples = 400\nvalue = [224.797, 12.823]'),
#  Text(0.005813953488372093, 0.3181818181818182, 'gini = 0.209\nsamples = 114\nvalue = [63.419, 8.548]'),
#  Text(0.01744186046511628, 0.3181818181818182, 'x[1] <= 0.5\ngini = 0.05\nsamples = 286\nvalue = [161.378, 4.274]'),
#  Text(0.011627906976744186, 0.22727272727272727, 'gini = 0.108\nsamples = 125\nvalue = [70.214, 4.274]'),
#  Text(0.023255813953488372, 0.22727272727272727, 'gini = 0.0\nsamples = 161\nvalue = [91.165, 0.0]'),
#  Text(0.046511627906976744, 0.4090909090909091, 'x[8] <= 58.5\ngini = 0.009\nsamples = 3396\nvalue = [1921.818, 8.548]'),
#  Text(0.040697674418604654, 0.3181818181818182, 'x[9] <= 30.5\ngini = 0.005\nsamples = 3272\nvalue = [1852.17, 4.274]'),
#  Text(0.03488372093023256, 0.22727272727272727, 'gini = -0.0\nsamples = 3123\nvalue = [1768.367, 0.0]'),
#  Text(0.046511627906976744, 0.22727272727272727, 'gini = 0.092\nsamples = 149\nvalue = [83.803, 4.274]'),
#  Text(0.05232558139534884, 0.3181818181818182, 'gini = 0.109\nsamples = 124\nvalue = [69.647, 4.274]'),
#  Text(0.08139534883720931, 0.5, 'x[4] <= 0.5\ngini = 0.093\nsamples = 1933\nvalue = [1087.18, 55.564]'),
#  Text(0.06976744186046512, 0.4090909090909091, 'x[1] <= 0.5\ngini = 0.066\nsamples = 1724\nvalue = [971.667, 34.193]'),
#  Text(0.06395348837209303, 0.3181818181818182, 'gini = 0.0\nsamples = 654\nvalue = [370.321, 0.0]'),
#  Text(0.0755813953488372, 0.3181818181818182, 'x[9] <= 13.5\ngini = 0.102\nsamples = 1070\nvalue = [601.347, 34.193]'),
#  Text(0.06395348837209303, 0.22727272727272727, 'x[9] <= 10.5\ngini = 0.184\nsamples = 335\nvalue = [186.859, 21.371]'),
#  Text(0.05813953488372093, 0.13636363636363635, 'x[8] <= 37.5\ngini = 0.116\nsamples = 230\nvalue = [129.103, 8.548]'),
#  Text(0.05232558139534884, 0.045454545454545456, 'gini = 0.23\nsamples = 101\nvalue = [56.058, 8.548]'),
#  Text(0.06395348837209303, 0.045454545454545456, 'gini = 0.0\nsamples = 129\nvalue = [73.045, 0.0]'),
#  Text(0.06976744186046512, 0.13636363636363635, 'gini = 0.297\nsamples = 105\nvalue = [57.756, 12.823]'),
#  Text(0.0872093023255814, 0.22727272727272727, 'x[10] <= 65.5\ngini = 0.058\nsamples = 735\nvalue = [414.488, 12.823]'),
#  Text(0.08139534883720931, 0.13636363636363635, 'gini = 0.133\nsamples = 198\nvalue = [110.983, 8.548]'),
#  Text(0.09302325581395349, 0.13636363636363635, 'x[10] <= 75.5\ngini = 0.027\nsamples = 537\nvalue = [303.505, 4.274]'),
#  Text(0.0872093023255814, 0.045454545454545456, 'gini = 0.0\nsamples = 434\nvalue = [245.748, 0.0]'),
#  Text(0.09883720930232558, 0.045454545454545456, 'gini = 0.128\nsamples = 103\nvalue = [57.756, 4.274]'),
#  Text(0.09302325581395349, 0.4090909090909091, 'x[8] <= 38.5\ngini = 0.263\nsamples = 209\nvalue = [115.513, 21.371]'),
#  Text(0.0872093023255814, 0.3181818181818182, 'gini = 0.352\nsamples = 106\nvalue = [57.756, 17.097]'),
#  Text(0.09883720930232558, 0.3181818181818182, 'gini = 0.128\nsamples = 103\nvalue = [57.756, 4.274]'),
#  Text(0.17078488372093023, 0.5909090909090909, 'x[0] <= 0.5\ngini = 0.252\nsamples = 6494\nvalue = [3594.49, 624.028]'),
#  Text(0.12790697674418605, 0.5, 'x[8] <= 28.5\ngini = 0.348\nsamples = 3036\nvalue = [1655.685, 478.707]'),
#  Text(0.11627906976744186, 0.4090909090909091, 'x[10] <= 103.5\ngini = 0.499\nsamples = 243\nvalue = [120.043, 132.499]'),
#  Text(0.11046511627906977, 0.3181818181818182, 'gini = 0.499\nsamples = 112\nvalue = [56.624, 51.29]'),
#  Text(0.12209302325581395, 0.3181818181818182, 'gini = 0.492\nsamples = 131\nvalue = [63.419, 81.209]'),
#  Text(0.13953488372093023, 0.4090909090909091, 'x[8] <= 60.5\ngini = 0.3\nsamples = 2793\nvalue = [1535.642, 346.208]'),
#  Text(0.13372093023255813, 0.3181818181818182, 'x[9] <= 3.5\ngini = 0.275\nsamples = 2672\nvalue = [1474.488, 290.643]'),
#  Text(0.12790697674418605, 0.22727272727272727, 'gini = 0.486\nsamples = 128\nvalue = [66.25, 47.016]'),
#  Text(0.13953488372093023, 0.22727272727272727, 'x[11] <= 91.5\ngini = 0.251\nsamples = 2544\nvalue = [1408.238, 243.628]'),
#  Text(0.13372093023255813, 0.13636363636363635, 'x[8] <= 35.5\ngini = 0.222\nsamples = 2372\nvalue = [1317.64, 192.338]'),
#  Text(0.12790697674418605, 0.045454545454545456, 'gini = 0.346\nsamples = 603\nvalue = [328.985, 94.032]'),
#  Text(0.13953488372093023, 0.045454545454545456, 'gini = 0.165\nsamples = 1769\nvalue = [988.655, 98.306]'),
#  Text(0.14534883720930233, 0.13636363636363635, 'gini = 0.462\nsamples = 172\nvalue = [90.598, 51.29]'),
#  Text(0.14534883720930233, 0.3181818181818182, 'gini = 0.499\nsamples = 121\nvalue = [61.154, 55.564]'),
#  Text(0.2136627906976744, 0.5, 'x[5] <= 0.5\ngini = 0.13\nsamples = 3458\nvalue = [1938.805, 145.322]'),
#  Text(0.20784883720930233, 0.4090909090909091, 'x[3] <= 0.5\ngini = 0.118\nsamples = 3296\nvalue = [1849.905, 123.951]'),
#  Text(0.18313953488372092, 0.3181818181818182, 'x[9] <= 22.5\ngini = 0.157\nsamples = 2036\nvalue = [1138.708, 106.854]'),
#  Text(0.1686046511627907, 0.22727272727272727, 'x[8] <= 38.5\ngini = 0.114\nsamples = 1649\nvalue = [925.802, 59.838]'),
#  Text(0.1569767441860465, 0.13636363636363635, 'x[8] <= 36.5\ngini = 0.166\nsamples = 836\nvalue = [467.148, 47.016]'),
#  Text(0.1511627906976744, 0.045454545454545456, 'gini = 0.131\nsamples = 701\nvalue = [392.97, 29.919]'),
#  Text(0.16279069767441862, 0.045454545454545456, 'gini = 0.304\nsamples = 135\nvalue = [74.177, 17.097]'),
#  Text(0.18023255813953487, 0.13636363636363635, 'x[8] <= 45.5\ngini = 0.053\nsamples = 813\nvalue = [458.654, 12.823]'),
#  Text(0.1744186046511628, 0.045454545454545456, 'gini = 0.0\nsamples = 357\nvalue = [202.148, 0.0]'),
#  Text(0.18604651162790697, 0.045454545454545456, 'gini = 0.091\nsamples = 456\nvalue = [256.507, 12.823]'),
#  Text(0.19767441860465115, 0.22727272727272727, 'x[9] <= 27.5\ngini = 0.296\nsamples = 387\nvalue = [212.906, 47.016]'),
#  Text(0.19186046511627908, 0.13636363636363635, 'gini = 0.467\nsamples = 151\nvalue = [79.274, 47.016]'),
#  Text(0.20348837209302326, 0.13636363636363635, 'gini = -0.0\nsamples = 236\nvalue = [133.633, 0.0]'),
#  Text(0.23255813953488372, 0.3181818181818182, 'x[9] <= 7.5\ngini = 0.046\nsamples = 1260\nvalue = [711.197, 17.097]'),
#  Text(0.22093023255813954, 0.22727272727272727, 'x[8] <= 44.5\ngini = 0.089\nsamples = 309\nvalue = [173.836, 8.548]'),
#  Text(0.21511627906976744, 0.13636363636363635, 'gini = 0.0\nsamples = 209\nvalue = [118.344, 0.0]'),
#  Text(0.22674418604651161, 0.13636363636363635, 'gini = 0.231\nsamples = 100\nvalue = [55.491, 8.548]'),
#  Text(0.2441860465116279, 0.22727272727272727, 'x[9] <= 23.5\ngini = 0.031\nsamples = 951\nvalue = [537.362, 8.548]'),
#  Text(0.23837209302325582, 0.13636363636363635, 'gini = -0.0\nsamples = 619\nvalue = [350.502, 0.0]'),
#  Text(0.25, 0.13636363636363635, 'x[8] <= 40.5\ngini = 0.084\nsamples = 332\nvalue = [186.859, 8.548]'),
#  Text(0.2441860465116279, 0.045454545454545456, 'gini = 0.128\nsamples = 207\nvalue = [116.079, 8.548]'),
#  Text(0.2558139534883721, 0.045454545454545456, 'gini = 0.0\nsamples = 125\nvalue = [70.78, 0.0]'),
#  Text(0.2194767441860465, 0.4090909090909091, 'gini = 0.312\nsamples = 162\nvalue = [88.9, 21.371]'),
#  Text(0.4007994186046512, 0.6818181818181818, 'x[0] <= 0.5\ngini = 0.433\nsamples = 10836\nvalue = [5780.742, 2679.903]'),
#  Text(0.34156976744186046, 0.5909090909090909, 'x[3] <= 0.5\ngini = 0.498\nsamples = 4558\nvalue = [2310.825, 2038.778]'),
#  Text(0.3226744186046512, 0.5, 'x[8] <= 60.5\ngini = 0.499\nsamples = 3716\nvalue = [1836.882, 2017.407]'),
#  Text(0.3023255813953488, 0.4090909090909091, 'x[8] <= 29.5\ngini = 0.5\nsamples = 3471\nvalue = [1743.452, 1675.473]'),
#  Text(0.27906976744186046, 0.3181818181818182, 'x[10] <= 177.5\ngini = 0.406\nsamples = 477\nvalue = [202.148, 512.9]'),
#  Text(0.26744186046511625, 0.22727272727272727, 'x[8] <= 26.5\ngini = 0.473\nsamples = 234\nvalue = [109.284, 175.241]'),
#  Text(0.2616279069767442, 0.13636363636363635, 'gini = 0.437\nsamples = 110\nvalue = [48.697, 102.58]'),
#  Text(0.27325581395348836, 0.13636363636363635, 'gini = 0.496\nsamples = 124\nvalue = [60.588, 72.661]'),
#  Text(0.29069767441860467, 0.22727272727272727, 'x[9] <= 16.5\ngini = 0.338\nsamples = 243\nvalue = [92.863, 337.659]'),
#  Text(0.28488372093023256, 0.13636363636363635, 'gini = 0.296\nsamples = 141\nvalue = [49.829, 226.531]'),
#  Text(0.29651162790697677, 0.13636363636363635, 'gini = 0.402\nsamples = 102\nvalue = [43.034, 111.128]'),
#  Text(0.32558139534883723, 0.3181818181818182, 'x[11] <= 22.5\ngini = 0.49\nsamples = 2994\nvalue = [1541.305, 1162.573]'),
#  Text(0.313953488372093, 0.22727272727272727, 'x[9] <= 3.5\ngini = 0.465\nsamples = 2612\nvalue = [1373.131, 799.269]'),
#  Text(0.3081395348837209, 0.13636363636363635, 'gini = 0.444\nsamples = 143\nvalue = [63.985, 128.225]'),
#  Text(0.31976744186046513, 0.13636363636363635, 'x[10] <= 228.5\ngini = 0.448\nsamples = 2469\nvalue = [1309.146, 671.044]'),
#  Text(0.313953488372093, 0.045454545454545456, 'gini = 0.427\nsamples = 2158\nvalue = [1153.43, 517.174]'),
#  Text(0.32558139534883723, 0.045454545454545456, 'gini = 0.5\nsamples = 311\nvalue = [155.716, 153.87]'),
#  Text(0.3372093023255814, 0.22727272727272727, 'x[10] <= 158.5\ngini = 0.433\nsamples = 382\nvalue = [168.173, 363.304]'),
#  Text(0.3313953488372093, 0.13636363636363635, 'gini = 0.492\nsamples = 110\nvalue = [53.227, 68.387]'),
#  Text(0.3430232558139535, 0.13636363636363635, 'x[8] <= 42.5\ngini = 0.404\nsamples = 272\nvalue = [114.947, 294.918]'),
#  Text(0.3372093023255814, 0.045454545454545456, 'gini = 0.428\nsamples = 167\nvalue = [73.045, 162.418]'),
#  Text(0.3488372093023256, 0.045454545454545456, 'gini = 0.365\nsamples = 105\nvalue = [41.902, 132.499]'),
#  Text(0.3430232558139535, 0.4090909090909091, 'x[9] <= 13.5\ngini = 0.337\nsamples = 245\nvalue = [93.43, 341.933]'),
#  Text(0.3372093023255814, 0.3181818181818182, 'gini = 0.379\nsamples = 107\nvalue = [43.6, 128.225]'),
#  Text(0.3488372093023256, 0.3181818181818182, 'gini = 0.307\nsamples = 138\nvalue = [49.829, 213.708]'),
#  Text(0.36046511627906974, 0.5, 'x[8] <= 33.5\ngini = 0.083\nsamples = 842\nvalue = [473.943, 21.371]'),
#  Text(0.3546511627906977, 0.4090909090909091, 'gini = 0.352\nsamples = 106\nvalue = [57.756, 17.097]'),
#  Text(0.36627906976744184, 0.4090909090909091, 'x[8] <= 38.5\ngini = 0.02\nsamples = 736\nvalue = [416.186, 4.274]'),
#  Text(0.36046511627906974, 0.3181818181818182, 'gini = 0.089\nsamples = 155\nvalue = [87.201, 4.274]'),
#  Text(0.37209302325581395, 0.3181818181818182, 'gini = 0.0\nsamples = 581\nvalue = [328.985, 0.0]'),
#  Text(0.46002906976744184, 0.5909090909090909, 'x[3] <= 0.5\ngini = 0.263\nsamples = 6278\nvalue = [3469.917, 641.125]'),
#  Text(0.42296511627906974, 0.5, 'x[9] <= 21.5\ngini = 0.348\nsamples = 3766\nvalue = [2053.752, 594.109]'),
#  Text(0.39244186046511625, 0.4090909090909091, 'x[8] <= 56.5\ngini = 0.313\nsamples = 3133\nvalue = [1719.104, 414.594]'),
#  Text(0.3866279069767442, 0.3181818181818182, 'x[9] <= 5.5\ngini = 0.292\nsamples = 3028\nvalue = [1667.01, 359.03]'),
#  Text(0.37209302325581395, 0.22727272727272727, 'x[11] <= 184.5\ngini = 0.444\nsamples = 403\nvalue = [214.039, 106.854]'),
#  Text(0.36627906976744184, 0.13636363636363635, 'x[9] <= 3.5\ngini = 0.488\nsamples = 260\nvalue = [134.199, 98.306]'),
#  Text(0.36046511627906974, 0.045454545454545456, 'gini = 0.5\nsamples = 110\nvalue = [54.925, 55.564]'),
#  Text(0.37209302325581395, 0.045454545454545456, 'gini = 0.455\nsamples = 150\nvalue = [79.274, 42.742]'),
#  Text(0.37790697674418605, 0.13636363636363635, 'gini = 0.175\nsamples = 143\nvalue = [79.84, 8.548]'),
#  Text(0.4011627906976744, 0.22727272727272727, 'x[9] <= 16.5\ngini = 0.252\nsamples = 2625\nvalue = [1452.971, 252.176]'),
#  Text(0.38953488372093026, 0.13636363636363635, 'x[4] <= 0.5\ngini = 0.302\nsamples = 1570\nvalue = [862.949, 196.612]'),
#  Text(0.38372093023255816, 0.045454545454545456, 'gini = 0.248\nsamples = 1140\nvalue = [631.357, 106.854]'),
#  Text(0.3953488372093023, 0.045454545454545456, 'gini = 0.403\nsamples = 430\nvalue = [231.592, 89.758]'),
#  Text(0.4127906976744186, 0.13636363636363635, 'x[8] <= 41.5\ngini = 0.157\nsamples = 1055\nvalue = [590.022, 55.564]'),
#  Text(0.4069767441860465, 0.045454545454545456, 'gini = 0.196\nsamples = 745\nvalue = [415.054, 51.29]'),
#  Text(0.4186046511627907, 0.045454545454545456, 'gini = 0.047\nsamples = 310\nvalue = [174.968, 4.274]'),
#  Text(0.39825581395348836, 0.3181818181818182, 'gini = 0.499\nsamples = 105\nvalue = [52.094, 55.564]'),
#  Text(0.45348837209302323, 0.4090909090909091, 'x[11] <= 3.0\ngini = 0.454\nsamples = 633\nvalue = [334.648, 179.515]'),
#  Text(0.4476744186046512, 0.3181818181818182, 'x[10] <= 214.5\ngini = 0.372\nsamples = 503\nvalue = [272.928, 89.758]'),
#  Text(0.4418604651162791, 0.22727272727272727, 'x[10] <= 171.5\ngini = 0.325\nsamples = 396\nvalue = [216.87, 55.564]'),
#  Text(0.436046511627907, 0.13636363636363635, 'x[10] <= 153.5\ngini = 0.425\nsamples = 235\nvalue = [125.705, 55.564]'),
#  Text(0.43023255813953487, 0.045454545454545456, 'gini = 0.349\nsamples = 135\nvalue = [73.611, 21.371]'),
#  Text(0.4418604651162791, 0.045454545454545456, 'gini = 0.478\nsamples = 100\nvalue = [52.094, 34.193]'),
#  Text(0.4476744186046512, 0.13636363636363635, 'gini = 0.0\nsamples = 161\nvalue = [91.165, 0.0]'),
#  Text(0.45348837209302323, 0.22727272727272727, 'gini = 0.471\nsamples = 107\nvalue = [56.058, 34.193]'),
#  Text(0.45930232558139533, 0.3181818181818182, 'gini = 0.483\nsamples = 130\nvalue = [61.72, 89.758]'),
#  Text(0.49709302325581395, 0.5, 'x[9] <= 29.5\ngini = 0.062\nsamples = 2512\nvalue = [1416.166, 47.016]'),
#  Text(0.49127906976744184, 0.4090909090909091, 'x[9] <= 20.5\ngini = 0.042\nsamples = 2397\nvalue = [1353.313, 29.919]'),
#  Text(0.47674418604651164, 0.3181818181818182, 'x[9] <= 4.5\ngini = 0.026\nsamples = 1709\nvalue = [966.005, 12.823]'),
#  Text(0.46511627906976744, 0.22727272727272727, 'x[8] <= 34.5\ngini = 0.106\nsamples = 257\nvalue = [144.391, 8.548]'),
#  Text(0.45930232558139533, 0.13636363636363635, 'gini = 0.0\nsamples = 122\nvalue = [69.081, 0.0]'),
#  Text(0.47093023255813954, 0.13636363636363635, 'gini = 0.183\nsamples = 135\nvalue = [75.31, 8.548]'),
#  Text(0.4883720930232558, 0.22727272727272727, 'x[8] <= 30.5\ngini = 0.01\nsamples = 1452\nvalue = [821.614, 4.274]'),
#  Text(0.48255813953488375, 0.13636363636363635, 'x[10] <= 180.5\ngini = 0.065\nsamples = 218\nvalue = [122.874, 4.274]'),
#  Text(0.47674418604651164, 0.045454545454545456, 'gini = 0.128\nsamples = 103\nvalue = [57.756, 4.274]'),
#  Text(0.4883720930232558, 0.045454545454545456, 'gini = 0.0\nsamples = 115\nvalue = [65.118, 0.0]'),
#  Text(0.4941860465116279, 0.13636363636363635, 'gini = -0.0\nsamples = 1234\nvalue = [698.74, 0.0]'),
#  Text(0.5058139534883721, 0.3181818181818182, 'x[8] <= 35.5\ngini = 0.081\nsamples = 688\nvalue = [387.308, 17.097]'),
#  Text(0.5, 0.22727272727272727, 'gini = 0.0\nsamples = 345\nvalue = [195.353, 0.0]'),
#  Text(0.5116279069767442, 0.22727272727272727, 'x[9] <= 27.5\ngini = 0.15\nsamples = 343\nvalue = [191.955, 17.097]'),
#  Text(0.5058139534883721, 0.13636363636363635, 'x[10] <= 178.5\ngini = 0.229\nsamples = 203\nvalue = [112.682, 17.097]'),
#  Text(0.5, 0.045454545454545456, 'gini = 0.226\nsamples = 103\nvalue = [57.19, 8.548]'),
#  Text(0.5116279069767442, 0.045454545454545456, 'gini = 0.231\nsamples = 100\nvalue = [55.491, 8.548]'),
#  Text(0.5174418604651163, 0.13636363636363635, 'gini = 0.0\nsamples = 140\nvalue = [79.274, 0.0]'),
#  Text(0.502906976744186, 0.4090909090909091, 'gini = 0.336\nsamples = 115\nvalue = [62.853, 17.097]'),
#  Text(0.502906976744186, 0.7727272727272727, 'x[10] <= 132.5\ngini = 0.199\nsamples = 587\nvalue = [161.945, 1286.524]'),
#  Text(0.49709302325581395, 0.6818181818181818, 'gini = 0.426\nsamples = 196\nvalue = [85.502, 192.338]'),
#  Text(0.5087209302325582, 0.6818181818181818, 'x[10] <= 167.5\ngini = 0.122\nsamples = 391\nvalue = [76.442, 1094.187]'),
#  Text(0.502906976744186, 0.5909090909090909, 'gini = 0.182\nsamples = 113\nvalue = [29.444, 260.724]'),
#  Text(0.5145348837209303, 0.5909090909090909, 'x[9] <= 16.5\ngini = 0.101\nsamples = 278\nvalue = [46.998, 833.463]'),
#  Text(0.5087209302325582, 0.5, 'gini = 0.084\nsamples = 174\nvalue = [25.481, 551.368]'),
#  Text(0.5203488372093024, 0.5, 'gini = 0.132\nsamples = 104\nvalue = [21.517, 282.095]'),
#  Text(0.7933321220930233, 0.8636363636363636, 'x[10] <= 521.5\ngini = 0.406\nsamples = 12522\nvalue = [5313.028, 13416.61]'),
#  Text(0.709484011627907, 0.7727272727272727, 'x[3] <= 0.5\ngini = 0.483\nsamples = 8534\nvalue = [4052.012, 5889.802]'),
#  Text(0.6617005813953488, 0.6818181818181818, 'x[6] <= 0.5\ngini = 0.439\nsamples = 6143\nvalue = [2727.577, 5667.545]'),
#  Text(0.6199127906976745, 0.5909090909090909, 'x[0] <= 0.5\ngini = 0.475\nsamples = 5696\nvalue = [2666.423, 4218.603]'),
#  Text(0.5857558139534884, 0.5, 'x[8] <= 60.5\ngini = 0.41\nsamples = 2907\nvalue = [1240.065, 3064.578]'),
#  Text(0.5668604651162791, 0.4090909090909091, 'x[11] <= 17.0\ngini = 0.432\nsamples = 2679\nvalue = [1177.779, 2560.226]'),
#  Text(0.5465116279069767, 0.3181818181818182, 'x[8] <= 29.5\ngini = 0.457\nsamples = 2287\nvalue = [1041.881, 1910.553]'),
#  Text(0.5348837209302325, 0.22727272727272727, 'x[8] <= 25.5\ngini = 0.321\nsamples = 350\nvalue = [129.669, 517.174]'),
#  Text(0.5290697674418605, 0.13636363636363635, 'gini = 0.215\nsamples = 109\nvalue = [31.709, 226.531]'),
#  Text(0.5406976744186046, 0.13636363636363635, 'x[9] <= 8.5\ngini = 0.377\nsamples = 241\nvalue = [97.959, 290.643]'),
#  Text(0.5348837209302325, 0.045454545454545456, 'gini = 0.439\nsamples = 102\nvalue = [45.299, 94.032]'),
#  Text(0.5465116279069767, 0.045454545454545456, 'gini = 0.333\nsamples = 139\nvalue = [52.66, 196.612]'),
#  Text(0.5581395348837209, 0.22727272727272727, 'x[9] <= 3.5\ngini = 0.478\nsamples = 1937\nvalue = [912.212, 1393.378]'),
#  Text(0.5523255813953488, 0.13636363636363635, 'gini = 0.278\nsamples = 118\nvalue = [40.203, 200.886]'),
#  Text(0.563953488372093, 0.13636363636363635, 'x[10] <= 317.5\ngini = 0.488\nsamples = 1819\nvalue = [872.009, 1192.493]'),
#  Text(0.5581395348837209, 0.045454545454545456, 'gini = 0.499\nsamples = 718\nvalue = [362.96, 329.111]'),
#  Text(0.5697674418604651, 0.045454545454545456, 'gini = 0.467\nsamples = 1101\nvalue = [509.05, 863.382]'),
#  Text(0.5872093023255814, 0.3181818181818182, 'x[9] <= 21.5\ngini = 0.286\nsamples = 392\nvalue = [135.898, 649.673]'),
#  Text(0.5813953488372093, 0.22727272727272727, 'x[10] <= 342.5\ngini = 0.328\nsamples = 279\nvalue = [104.754, 401.772]'),
#  Text(0.5755813953488372, 0.13636363636363635, 'gini = 0.385\nsamples = 146\nvalue = [60.021, 170.967]'),
#  Text(0.5872093023255814, 0.13636363636363635, 'gini = 0.272\nsamples = 133\nvalue = [44.733, 230.805]'),
#  Text(0.5930232558139535, 0.22727272727272727, 'gini = 0.198\nsamples = 113\nvalue = [31.143, 247.902]'),
#  Text(0.6046511627906976, 0.4090909090909091, 'x[9] <= 14.5\ngini = 0.196\nsamples = 228\nvalue = [62.286, 504.352]'),
#  Text(0.5988372093023255, 0.3181818181818182, 'gini = 0.258\nsamples = 127\nvalue = [41.336, 230.805]'),
#  Text(0.6104651162790697, 0.3181818181818182, 'gini = 0.132\nsamples = 101\nvalue = [20.951, 273.547]'),
#  Text(0.6540697674418605, 0.5, 'x[10] <= 341.5\ngini = 0.494\nsamples = 2789\nvalue = [1426.358, 1154.025]'),
#  Text(0.627906976744186, 0.4090909090909091, 'x[9] <= 5.5\ngini = 0.447\nsamples = 1473\nvalue = [781.411, 397.498]'),
#  Text(0.622093023255814, 0.3181818181818182, 'gini = 0.481\nsamples = 165\nvalue = [78.141, 115.403]'),
#  Text(0.6337209302325582, 0.3181818181818182, 'x[9] <= 20.5\ngini = 0.409\nsamples = 1308\nvalue = [703.27, 282.095]'),
#  Text(0.622093023255814, 0.22727272727272727, 'x[9] <= 18.5\ngini = 0.355\nsamples = 1021\nvalue = [556.047, 166.693]'),
#  Text(0.6162790697674418, 0.13636363636363635, 'x[8] <= 36.5\ngini = 0.379\nsamples = 881\nvalue = [477.34, 162.418]'),
#  Text(0.6104651162790697, 0.045454545454545456, 'gini = 0.433\nsamples = 432\nvalue = [230.46, 106.854]'),
#  Text(0.622093023255814, 0.045454545454545456, 'gini = 0.3\nsamples = 449\nvalue = [246.881, 55.564]'),
#  Text(0.627906976744186, 0.13636363636363635, 'gini = 0.098\nsamples = 140\nvalue = [78.707, 4.274]'),
#  Text(0.6453488372093024, 0.22727272727272727, 'x[8] <= 41.5\ngini = 0.493\nsamples = 287\nvalue = [147.222, 115.403]'),
#  Text(0.6395348837209303, 0.13636363636363635, 'gini = 0.473\nsamples = 184\nvalue = [96.261, 59.838]'),
#  Text(0.6511627906976745, 0.13636363636363635, 'gini = 0.499\nsamples = 103\nvalue = [50.962, 55.564]'),
#  Text(0.6802325581395349, 0.4090909090909091, 'x[8] <= 52.5\ngini = 0.497\nsamples = 1316\nvalue = [644.947, 756.528]'),
#  Text(0.6744186046511628, 0.3181818181818182, 'x[10] <= 484.5\ngini = 0.499\nsamples = 1204\nvalue = [596.25, 645.399]'),
#  Text(0.6686046511627907, 0.22727272727272727, 'x[9] <= 22.5\ngini = 0.5\nsamples = 1039\nvalue = [520.941, 508.626]'),
#  Text(0.6627906976744186, 0.13636363636363635, 'x[9] <= 18.5\ngini = 0.497\nsamples = 913\nvalue = [463.75, 401.772]'),
#  Text(0.6569767441860465, 0.045454545454545456, 'gini = 0.5\nsamples = 741\nvalue = [372.02, 359.03]'),
#  Text(0.6686046511627907, 0.045454545454545456, 'gini = 0.434\nsamples = 172\nvalue = [91.731, 42.742]'),
#  Text(0.6744186046511628, 0.13636363636363635, 'gini = 0.454\nsamples = 126\nvalue = [57.19, 106.854]'),
#  Text(0.6802325581395349, 0.22727272727272727, 'gini = 0.458\nsamples = 165\nvalue = [75.31, 136.773]'),
#  Text(0.686046511627907, 0.3181818181818182, 'gini = 0.424\nsamples = 112\nvalue = [48.697, 111.128]'),
#  Text(0.7034883720930233, 0.5909090909090909, 'x[0] <= 0.5\ngini = 0.078\nsamples = 447\nvalue = [61.154, 1448.943]'),
#  Text(0.6976744186046512, 0.5, 'x[10] <= 312.5\ngini = 0.056\nsamples = 320\nvalue = [33.408, 1115.558]'),
#  Text(0.6918604651162791, 0.4090909090909091, 'gini = 0.037\nsamples = 135\nvalue = [9.626, 504.352]'),
#  Text(0.7034883720930233, 0.4090909090909091, 'gini = 0.072\nsamples = 185\nvalue = [23.782, 611.206]'),
#  Text(0.7093023255813954, 0.5, 'gini = 0.142\nsamples = 127\nvalue = [27.746, 333.385]'),
#  Text(0.7572674418604651, 0.6818181818181818, 'x[10] <= 459.5\ngini = 0.246\nsamples = 2391\nvalue = [1324.435, 222.257]'),
#  Text(0.7412790697674418, 0.5909090909090909, 'x[10] <= 368.5\ngini = 0.148\nsamples = 2097\nvalue = [1173.815, 102.58]'),
#  Text(0.7267441860465116, 0.5, 'x[0] <= 0.5\ngini = 0.067\nsamples = 1473\nvalue = [830.108, 29.919]'),
#  Text(0.7151162790697675, 0.4090909090909091, 'x[10] <= 317.5\ngini = 0.196\nsamples = 371\nvalue = [206.678, 25.645]'),
#  Text(0.7093023255813954, 0.3181818181818182, 'x[10] <= 285.5\ngini = 0.274\nsamples = 237\nvalue = [130.801, 25.645]'),
#  Text(0.7034883720930233, 0.22727272727272727, 'gini = 0.182\nsamples = 136\nvalue = [75.876, 8.548]'),
#  Text(0.7151162790697675, 0.22727272727272727, 'gini = 0.362\nsamples = 101\nvalue = [54.925, 17.097]'),
#  Text(0.7209302325581395, 0.3181818181818182, 'gini = 0.0\nsamples = 134\nvalue = [75.876, 0.0]'),
#  Text(0.7383720930232558, 0.4090909090909091, 'x[8] <= 32.5\ngini = 0.014\nsamples = 1102\nvalue = [623.43, 4.274]'),
#  Text(0.7325581395348837, 0.3181818181818182, 'x[8] <= 30.5\ngini = 0.043\nsamples = 338\nvalue = [190.823, 4.274]'),
#  Text(0.7267441860465116, 0.22727272727272727, 'gini = 0.0\nsamples = 235\nvalue = [133.066, 0.0]'),
#  Text(0.7383720930232558, 0.22727272727272727, 'gini = 0.128\nsamples = 103\nvalue = [57.756, 4.274]'),
#  Text(0.7441860465116279, 0.3181818181818182, 'gini = -0.0\nsamples = 764\nvalue = [432.607, 0.0]'),
#  Text(0.7558139534883721, 0.5, 'x[8] <= 30.5\ngini = 0.288\nsamples = 624\nvalue = [343.708, 72.661]'),
#  Text(0.75, 0.4090909090909091, 'gini = 0.474\nsamples = 104\nvalue = [54.359, 34.193]'),
#  Text(0.7616279069767442, 0.4090909090909091, 'x[8] <= 50.5\ngini = 0.207\nsamples = 520\nvalue = [289.349, 38.468]'),
#  Text(0.7558139534883721, 0.3181818181818182, 'x[8] <= 38.5\ngini = 0.156\nsamples = 409\nvalue = [228.761, 21.371]'),
#  Text(0.75, 0.22727272727272727, 'x[8] <= 34.5\ngini = 0.256\nsamples = 218\nvalue = [120.609, 21.371]'),
#  Text(0.7441860465116279, 0.13636363636363635, 'gini = 0.0\nsamples = 102\nvalue = [57.756, 0.0]'),
#  Text(0.7558139534883721, 0.13636363636363635, 'gini = 0.379\nsamples = 116\nvalue = [62.853, 21.371]'),
#  Text(0.7616279069767442, 0.22727272727272727, 'gini = 0.0\nsamples = 191\nvalue = [108.152, 0.0]'),
#  Text(0.7674418604651163, 0.3181818181818182, 'gini = 0.343\nsamples = 111\nvalue = [60.588, 17.097]'),
#  Text(0.7732558139534884, 0.5909090909090909, 'x[9] <= 19.5\ngini = 0.493\nsamples = 294\nvalue = [150.62, 119.677]'),
#  Text(0.7674418604651163, 0.5, 'gini = 0.5\nsamples = 191\nvalue = [95.128, 98.306]'),
#  Text(0.7790697674418605, 0.5, 'gini = 0.401\nsamples = 103\nvalue = [55.491, 21.371]'),
#  Text(0.8771802325581395, 0.7727272727272727, 'x[10] <= 648.5\ngini = 0.246\nsamples = 3988\nvalue = [1261.016, 7526.808]'),
#  Text(0.8299418604651163, 0.6818181818181818, 'x[3] <= 0.5\ngini = 0.358\nsamples = 1426\nvalue = [562.842, 1846.44]'),
#  Text(0.8052325581395349, 0.5909090909090909, 'x[0] <= 0.5\ngini = 0.312\nsamples = 1052\nvalue = [383.911, 1598.538]'),
#  Text(0.7906976744186046, 0.5, 'x[9] <= 26.5\ngini = 0.263\nsamples = 516\nvalue = [169.872, 923.22]'),
#  Text(0.7848837209302325, 0.4090909090909091, 'x[10] <= 579.5\ngini = 0.248\nsamples = 408\nvalue = [129.669, 765.076]'),
#  Text(0.7790697674418605, 0.3181818181818182, 'x[8] <= 40.5\ngini = 0.225\nsamples = 210\nvalue = [62.853, 423.143]'),
#  Text(0.7732558139534884, 0.22727272727272727, 'gini = 0.198\nsamples = 103\nvalue = [28.312, 226.531]'),
#  Text(0.7848837209302325, 0.22727272727272727, 'gini = 0.254\nsamples = 107\nvalue = [34.541, 196.612]'),
#  Text(0.7906976744186046, 0.3181818181818182, 'gini = 0.273\nsamples = 198\nvalue = [66.816, 341.933]'),
#  Text(0.7965116279069767, 0.4090909090909091, 'gini = 0.323\nsamples = 108\nvalue = [40.203, 158.144]'),
#  Text(0.8197674418604651, 0.5, 'x[8] <= 35.5\ngini = 0.365\nsamples = 536\nvalue = [214.039, 675.318]'),
#  Text(0.8081395348837209, 0.4090909090909091, 'x[9] <= 15.5\ngini = 0.318\nsamples = 247\nvalue = [91.165, 367.578]'),
#  Text(0.8023255813953488, 0.3181818181818182, 'gini = 0.241\nsamples = 116\nvalue = [36.239, 222.257]'),
#  Text(0.813953488372093, 0.3181818181818182, 'gini = 0.398\nsamples = 131\nvalue = [54.925, 145.322]'),
#  Text(0.8313953488372093, 0.4090909090909091, 'x[8] <= 45.5\ngini = 0.408\nsamples = 289\nvalue = [122.874, 307.74]'),
#  Text(0.8255813953488372, 0.3181818181818182, 'gini = 0.437\nsamples = 188\nvalue = [83.237, 175.241]'),
#  Text(0.8372093023255814, 0.3181818181818182, 'gini = 0.354\nsamples = 101\nvalue = [39.637, 132.499]'),
#  Text(0.8546511627906976, 0.5909090909090909, 'x[8] <= 45.5\ngini = 0.487\nsamples = 374\nvalue = [178.932, 247.902]'),
#  Text(0.8488372093023255, 0.5, 'x[8] <= 34.5\ngini = 0.465\nsamples = 270\nvalue = [124.573, 213.708]'),
#  Text(0.8430232558139535, 0.4090909090909091, 'gini = 0.492\nsamples = 137\nvalue = [66.25, 85.483]'),
#  Text(0.8546511627906976, 0.4090909090909091, 'gini = 0.43\nsamples = 133\nvalue = [58.323, 128.225]'),
#  Text(0.8604651162790697, 0.5, 'gini = 0.474\nsamples = 104\nvalue = [54.359, 34.193]'),
#  Text(0.9244186046511628, 0.6818181818181818, 'x[10] <= 827.5\ngini = 0.195\nsamples = 2562\nvalue = [698.174, 5680.368]'),
#  Text(0.8924418604651163, 0.5909090909090909, 'x[1] <= 0.5\ngini = 0.253\nsamples = 1114\nvalue = [358.996, 2051.6]'),
#  Text(0.872093023255814, 0.5, 'x[8] <= 33.5\ngini = 0.352\nsamples = 378\nvalue = [147.789, 500.078]'),
#  Text(0.8662790697674418, 0.4090909090909091, 'gini = 0.277\nsamples = 115\nvalue = [39.071, 196.612]'),
#  Text(0.877906976744186, 0.4090909090909091, 'x[0] <= 0.5\ngini = 0.388\nsamples = 263\nvalue = [108.718, 303.466]'),
#  Text(0.872093023255814, 0.3181818181818182, 'gini = 0.303\nsamples = 101\nvalue = [36.239, 158.144]'),
#  Text(0.8837209302325582, 0.3181818181818182, 'gini = 0.444\nsamples = 162\nvalue = [72.479, 145.322]'),
#  Text(0.9127906976744186, 0.5, 'x[11] <= 0.0\ngini = 0.211\nsamples = 736\nvalue = [211.207, 1551.523]'),
#  Text(0.9069767441860465, 0.4090909090909091, 'x[0] <= 0.5\ngini = 0.234\nsamples = 560\nvalue = [171.571, 1098.461]'),
#  Text(0.8953488372093024, 0.3181818181818182, 'x[10] <= 739.5\ngini = 0.2\nsamples = 286\nvalue = [79.274, 624.028]'),
#  Text(0.8895348837209303, 0.22727272727272727, 'gini = 0.182\nsamples = 183\nvalue = [47.564, 423.143]'),
#  Text(0.9011627906976745, 0.22727272727272727, 'gini = 0.235\nsamples = 103\nvalue = [31.709, 200.886]'),
#  Text(0.9186046511627907, 0.3181818181818182, 'x[9] <= 15.5\ngini = 0.273\nsamples = 274\nvalue = [92.297, 474.433]'),
#  Text(0.9127906976744186, 0.22727272727272727, 'gini = 0.209\nsamples = 119\nvalue = [33.974, 252.176]'),
#  Text(0.9244186046511628, 0.22727272727272727, 'gini = 0.329\nsamples = 155\nvalue = [58.323, 222.257]'),
#  Text(0.9186046511627907, 0.4090909090909091, 'gini = 0.148\nsamples = 176\nvalue = [39.637, 453.062]'),
#  Text(0.9563953488372093, 0.5909090909090909, 'x[1] <= 0.5\ngini = 0.156\nsamples = 1448\nvalue = [339.178, 3628.768]'),
#  Text(0.936046511627907, 0.5, 'x[10] <= 999.5\ngini = 0.205\nsamples = 476\nvalue = [134.199, 1021.526]'),
#  Text(0.9302325581395349, 0.4090909090909091, 'gini = 0.263\nsamples = 172\nvalue = [56.624, 307.74]'),
#  Text(0.9418604651162791, 0.4090909090909091, 'x[9] <= 18.5\ngini = 0.177\nsamples = 304\nvalue = [77.575, 713.786]'),
#  Text(0.936046511627907, 0.3181818181818182, 'gini = 0.205\nsamples = 195\nvalue = [54.925, 418.868]'),
#  Text(0.9476744186046512, 0.3181818181818182, 'gini = 0.132\nsamples = 109\nvalue = [22.65, 294.918]'),
#  Text(0.9767441860465116, 0.5, 'x[8] <= 54.5\ngini = 0.135\nsamples = 972\nvalue = [204.979, 2607.242]'),
#  Text(0.9709302325581395, 0.4090909090909091, 'x[9] <= 15.5\ngini = 0.125\nsamples = 836\nvalue = [166.474, 2316.598]'),
#  Text(0.9593023255813954, 0.3181818181818182, 'x[9] <= 7.5\ngini = 0.106\nsamples = 416\nvalue = [73.045, 1226.686]'),
#  Text(0.9534883720930233, 0.22727272727272727, 'gini = 0.141\nsamples = 182\nvalue = [39.637, 478.707]'),
#  Text(0.9651162790697675, 0.22727272727272727, 'x[10] <= 1098.0\ngini = 0.082\nsamples = 234\nvalue = [33.408, 747.979]'),
#  Text(0.9593023255813954, 0.13636363636363635, 'gini = 0.067\nsamples = 132\nvalue = [15.855, 444.513]'),
#  Text(0.9709302325581395, 0.13636363636363635, 'gini = 0.103\nsamples = 102\nvalue = [17.553, 303.466]'),
#  Text(0.9825581395348837, 0.3181818181818182, 'x[10] <= 921.5\ngini = 0.145\nsamples = 420\nvalue = [93.43, 1089.913]'),
#  Text(0.9767441860465116, 0.22727272727272727, 'gini = 0.201\nsamples = 106\nvalue = [29.444, 230.805]'),
#  Text(0.9883720930232558, 0.22727272727272727, 'x[10] <= 1206.5\ngini = 0.129\nsamples = 314\nvalue = [63.985, 859.108]'),
#  Text(0.9825581395348837, 0.13636363636363635, 'gini = 0.149\nsamples = 188\nvalue = [42.468, 482.981]'),
#  Text(0.9941860465116279, 0.13636363636363635, 'gini = 0.102\nsamples = 126\nvalue = [21.517, 376.127]'),
#  Text(0.9825581395348837, 0.4090909090909091, 'gini = 0.207\nsamples = 136\nvalue = [38.504, 290.643]')]

# %%
fig.savefig('best_estimator_balanced_recall.png')
